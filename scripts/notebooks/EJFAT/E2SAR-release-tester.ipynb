# %% [markdown]
# # EJFAT LB Control Plane Tester
#
# This notebook stands up a slice of 3 nodes - sender, receiver and cpnode. The control plane daemon is deployed on the `cpnode` node in a 'mock' configuration (with no FPGA). DAQ and worker node code can be deployed on `sender` and `receiver` nodes for testing. The slice uses 'shared' and is created within a single FABRIC site for simplicity. It uses a single L2 bridge connection with RFC1918 IPv4 addressing, allowing all nodes to talk to each other. It is possible to run the dataplane assuming a single worker can keep up with a single sender since no actual load balancer is present in this configuration.
#
# This notebook uses the E2SAR release debian pacakges found at [Github releases](https://github.com/JeffersonLab/E2SAR/releases). We need this release to create our shared JNI native library
#
# Slice example:
#
# <div>
#     <img src="figs/UDP LB Control Plane Testing slice.png" width=500>
# </div>
#
# ## Preparation and overview
#
# - Be sure to [generate a keypair for Jupyter Hub](GitHubSSH.ipynb) and register it with GitHub - the keys will be used to check out the code from private repositories, like [UDPLBd](https://github.com/esnet/udplbd) and [E2SAR](https://github.com/JeffersonLab/E2SAR).
# - Note that for E2SAR development and testing sender and receiver node compile/build environments will be setup via post-boot scripts ([sender](post-boot/sender.sh) and [receiver](post-boot/recver.sh))
# - The E2SAR [debian/rpm package]((https://github.com/JeffersonLab/E2SAR/releases)) comes with all necessary dependencies.
# - This does not setup the control plane node for anything, but testing a specific version - you can set which branch of UDPLBd to check out and a containerized version is built and stood up.

# %% [markdown]
# # EJFAT LB Control Plane Tester
#
# This notebook stands up a slice of 3 nodes - sender, receiver and cpnode. The control plane daemon is deployed on the `cpnode` node in a 'mock' configuration (with no FPGA). DAQ and worker node code can be deployed on `sender` and `receiver` nodes for testing. The slice uses 'shared' and is created within a single FABRIC site for simplicity. It uses a single L2 bridge connection with RFC1918 IPv4 addressing, allowing all nodes to talk to each other. It is possible to run the dataplane assuming a single worker can keep up with a single sender since no actual load balancer is present in this configuration.
#
# This notebook uses the E2SAR release debian pacakges found at [Github releases](https://github.com/JeffersonLab/E2SAR/releases). If you want to build E2SAR from scratch, you can use the [E2SAR Dev tester](E2SAR-development-tester.ipynb) notebook.
#
# Slice example:
#
# <div>
#     <img src="figs/UDP LB Control Plane Testing slice.png" width=500>
# </div>
#
# ## Preparation and overview
#
# - Be sure to [generate a keypair for Jupyter Hub](https://github.com/JeffersonLab/E2SAR/blob/main/scripts/notebooks/EJFAT/GitHubSSH.ipynb) and register it with GitHub - the keys will be used to check out the code from private repositories, like [UDPLBd](https://github.com/esnet/udplbd) and [E2SAR](https://github.com/JeffersonLab/E2SAR).
# - Note that for E2SAR development and testing sender and receiver node compile/build environments will be setup via post-boot scripts ([sender](post-boot/sender.sh) and [receiver](post-boot/recver.sh))
# - The E2SAR [debian package]((https://github.com/JeffersonLab/E2SAR/releases)) comes with all necessary dependencies.
# - This does not setup the control plane node for anything, but testing a specific version - you can set which branch of UDPLBd to check out and a containerized version is built and stood up.

# %% [markdown]
# ## Preamble
#
# This cell must be executed whether you are creating a new slice or continuing work on the old one. If you are continuing work, you then skip the slice create section and proceed to wherever you left off.

# %%
#
# EDIT THIS
#
# if you want to force a site instead of using random
# Pick 'UCSD', 'SRI', 'FIU' or 'TOKY' - these sites have
# IPv4. Other sites use IPv6 management and have trouble
# retrieving git-lfs artifacts.

 ## NEED TO USE IPV4 HERE AS MAVEN CENTRAL REPO DOES NOT WORK WITH IPV6. THERE IS ALSO AN ISSUE WHERE GRADLE CANNOT BE DOWNLOADED ON IPV6

site_override = 'SRI'
#site_override = None

# GitHub SSH key file (private) registered using the GitHubSSH.ipynb notebook referenced above
github_key = '/home/fabric/work/fabric_config/github_ecdsa'
signing_key = '/home/fabric/work/fabric_config/signing'

# branches for UDPLBd and E2SAR that we want checked out on the VMs
udplbd_branch = 'main'
e2sar_branch = 'e2sar-java' #there is no branch called release, this just keeps this notebooks slice separate.

# which of the available config files to use with UDPLBd
udplbd_config = 'lb_mock-tls.yml'

#base distro type - either default or docker
distro_types = ['default','docker']
distro_type = distro_types[0]

# base distro 'ubuntu' or 'rocky'
distro_name = 'ubuntu'

#base distro version, currently only for ubuntu 20,22,24. E2SAR dependencies will be 
#downloaded for the appropriate versions.
distro_version = '22'

# note that the below is distribution specific ('ubuntu' for ubuntu and so on)
home_location = {
    'ubuntu': '/home/ubuntu',
    'rocky' : '/home/rocky'
}[distro_name]

vm_key_location = f'{home_location}/.ssh/github_ecdsa'
sign_key_location = f'{home_location}/.ssh/signing'

# which test suites in E2SAR to run (leave empty to run all)
# you can set 'unit' or 'live' to run unit or live tests only
e2sar_test_suite = ''

# name of the network connecting the nodes
net_name = 'site_bridge_net'

# url of e2sar deb. Find the appropriate version for the OS at https://github.com/JeffersonLab/E2SAR/releases
static_release_url = 'https://github.com/JeffersonLab/E2SAR/releases/download/' # don't need to change this
e2sar_release_ver = 'E2SAR-main-0.1.5'
e2sar_release_artifact = "e2sar_0.1.5_amd64.deb"
e2sar_release_url = static_release_url + e2sar_release_ver + "-" + distro_name + "-" + distro_version + ".04/" + e2sar_release_artifact

#
# SHOULDN'T NEED TO EDIT BELOW
#
# Preamble
import json
from datetime import datetime
from datetime import timezone
from datetime import timedelta

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

fablib = fablib_manager()             
fablib.show_config();

# Using docker image for cpnode by default
distro_image = distro_type + '_' + distro_name + '_' + distro_version
cp_distro_image = distro_types[1] + '_' + distro_name + '_' + distro_version

# variable settings
slice_name = f'UDP LB Control Plane Testing with udplbd[{udplbd_branch}], e2sar[{e2sar_branch}] on {distro_name}'
slice_name = "UDP LB Control Plane Testing with udplbd[develop], e2sar[e2sar-java] on ubuntu"

# for each node specify IP address (assuming /24), OS image
# note that most of the keys in these dictionaries map directly
# onto parameters to add_node()
node_config = {
    'sender': {
        'ip':'192.168.0.1', 
        'image': distro_image,
        'cores': 8,
        'ram': 24,
        'disk': 100 },
    'recver': {
        'ip':'192.168.0.2', 
        'image':distro_image,
        'cores':8,
        'ram': 24,
        'disk': 100 },
    'cpnode': {
        'ip':'192.168.0.3', 
        'image':distro_image,
        'cores':8,
        'ram': 8,
        'disk': 100 },
}
# skip these keys as they are not part of add_node params
skip_keys = ['ip']
# this is the NIC to use
nic_model = 'NIC_Basic'
# the subnet should match IPs
subnet = IPv4Network("192.168.1.0/24")

def execute_single_node(node, commands):
    for command in commands:
        print(f'\tExecuting "{command}" on node {node.get_name()}')
        #stdout, stderr = node.execute(command, quiet=True, output_file=node.get_name() + '_install.log')
        stdout, stderr = node.execute(command)
    if not stderr and len(stderr) > 0:
        print(f'Error encountered with "{command}": {stderr}')
        
def execute_commands(node, commands):
    if isinstance(node, list):
        for n in node:
            execute_single_node(n, commands)
    else:
        execute_single_node(node, commands)

def get_management_os_interface(node) -> str or None:
        """
        Gets the name of the management interface used by the node's
        operating system. 

        :return: interface name
        :rtype: String
        """
        stdout, stderr = node.execute("sudo ip -j route list", quiet=True)
        stdout_json = json.loads(stdout)

        for i in stdout_json:
            if i["dst"] == "default":
                return i["dev"]

        stdout, stderr = node.execute("sudo ip -6 -j route list", quiet=True)
        stdout_json = json.loads(stdout)

        for i in stdout_json:
            if i["dst"] == "default":
                return i["dev"]

        return None
# Out:
# <style type="text/css">
# #T_88720 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_88720 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_88720 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_88720_row0_col0, #T_88720_row0_col1, #T_88720_row1_col0, #T_88720_row1_col1, #T_88720_row2_col0, #T_88720_row2_col1, #T_88720_row3_col0, #T_88720_row3_col1, #T_88720_row4_col0, #T_88720_row4_col1, #T_88720_row5_col0, #T_88720_row5_col1, #T_88720_row6_col0, #T_88720_row6_col1, #T_88720_row7_col0, #T_88720_row7_col1, #T_88720_row8_col0, #T_88720_row8_col1, #T_88720_row9_col0, #T_88720_row9_col1, #T_88720_row10_col0, #T_88720_row10_col1, #T_88720_row11_col0, #T_88720_row11_col1, #T_88720_row12_col0, #T_88720_row12_col1, #T_88720_row13_col0, #T_88720_row13_col1, #T_88720_row14_col0, #T_88720_row14_col1, #T_88720_row15_col0, #T_88720_row15_col1, #T_88720_row16_col0, #T_88720_row16_col1, #T_88720_row17_col0, #T_88720_row17_col1, #T_88720_row18_col0, #T_88720_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_88720">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_88720_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_88720_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_88720_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_88720_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_88720_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_88720_row4_col1" class="data row4 col1" >bbe0d94c-736b-477a-a2e6-fef9fe7ac9ca</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row5_col0" class="data row5 col0" >Bastion Host</td>
#       <td id="T_88720_row5_col1" class="data row5 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row6_col0" class="data row6 col0" >Bastion Username</td>
#       <td id="T_88720_row6_col1" class="data row6 col1" >srinivas_0000202712</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row7_col0" class="data row7 col0" >Bastion Private Key File</td>
#       <td id="T_88720_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/fabric-bastion-key</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_88720_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_88720_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row10_col0" class="data row10 col0" >Sites to avoid</td>
#       <td id="T_88720_row10_col1" class="data row10 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_88720_row11_col0" class="data row11 col0" >SSH Command Line</td>
#       <td id="T_88720_row11_col1" class="data row11 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_88720_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row13_col0" class="data row13 col0" >Log File</td>
#       <td id="T_88720_row13_col1" class="data row13 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row14_col0" class="data row14 col0" >Bastion SSH Config File</td>
#       <td id="T_88720_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row15_col0" class="data row15 col0" >Version</td>
#       <td id="T_88720_row15_col1" class="data row15 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row16_col0" class="data row16 col0" >Data directory</td>
#       <td id="T_88720_row16_col1" class="data row16 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row17_col0" class="data row17 col0" >Artifact Manager</td>
#       <td id="T_88720_row17_col1" class="data row17 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_88720_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_88720_row18_col1" class="data row18 col1" >EJFAT</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the slice

# %%
# list all slices I have running
output_dataframe = fablib.list_slices(output='pandas')
if output_dataframe:
    print(output_dataframe)
else:
    print('No active slices under this project')
# Out:
# <style type="text/css">
# #T_14621 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_14621 th {
#   text-align: left;
# }
# #T_14621 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_14621 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_14621 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_14621_row0_col0, #T_14621_row0_col1, #T_14621_row0_col2, #T_14621_row0_col3, #T_14621_row0_col4, #T_14621_row0_col5 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_14621">
#   <caption>Slices</caption>
#   <thead>
#     <tr>
#       <th id="T_14621_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_14621_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_14621_level0_col2" class="col_heading level0 col2" >Lease Expiration (UTC)</th>
#       <th id="T_14621_level0_col3" class="col_heading level0 col3" >Lease Start (UTC)</th>
#       <th id="T_14621_level0_col4" class="col_heading level0 col4" >Project ID</th>
#       <th id="T_14621_level0_col5" class="col_heading level0 col5" >State</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_14621_row0_col0" class="data row0 col0" >5210f023-b755-498a-ba3a-956056527da8</td>
#       <td id="T_14621_row0_col1" class="data row0 col1" >4-node U280 LB Tester Slice using ubuntu22 1</td>
#       <td id="T_14621_row0_col2" class="data row0 col2" >2025-02-24 01:30:08 +0000</td>
#       <td id="T_14621_row0_col3" class="data row0 col3" >2025-01-16 21:08:36 +0000</td>
#       <td id="T_14621_row0_col4" class="data row0 col4" >bbe0d94c-736b-477a-a2e6-fef9fe7ac9ca</td>
#       <td id="T_14621_row0_col5" class="data row0 col5" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <pandas.io.formats.style.Styler object at 0x7a3b84f11d10>

# %% [markdown]
# If your slice is already active you can skip to the 'Get Slice Details' section.

# %%
# List available images (this step is optional)
available_images = fablib.get_image_names()

print(f'Available images are: {available_images}')
# Out:
# Available images are: ['default_centos8_stream', 'default_centos9_stream', 'default_centos_7', 'default_centos_8', 'default_debian_11', 'default_debian_12', 'default_fedora_39', 'default_fedora_40', 'default_freebsd_13_zfs', 'default_freebsd_14_zfs', 'default_kali', 'default_openbsd_7', 'default_rocky_8', 'default_rocky_9', 'default_ubuntu_20', 'default_ubuntu_22', 'default_ubuntu_24', 'docker_rocky_8', 'docker_rocky_9', 'docker_ubuntu_20', 'docker_ubuntu_22']

# %%
# find an available site in continental US
lon_west=-124.3993243
lon_east=-69.9721573

# getting a random site make take a bit of time
if not site_override:
    selected_site = fablib.get_random_site(filter_function=lambda x: x['location'][1] < lon_east
                                              and x['location'][1] > lon_west) 
else:
    selected_site = site_override

if selected_site:
    print(f'Selected site is {selected_site}')
else:
    print('Unable to find a site matching the requirements')

# write selected site into node attributes
for n in node_config:
    node_config[n]['site'] = selected_site
# Out:
# Selected site is SRI

# %%
# build a slice
slice = fablib.new_slice(name=slice_name)

# create a network
net1 = slice.add_l2network(name=net_name, subnet=subnet)

nodes = dict()
# create  nodes for sending and receiving with a selected network card
# use subnet address assignment
for node_name, node_attribs in node_config.items():
    print(f"{node_name=} {node_attribs['ip']}")
    nodes[node_name] = slice.add_node(name=node_name, **{x: node_attribs[x] for x in node_attribs if x not in skip_keys})
    nic_interface = nodes[node_name].add_component(model=nic_model, name='_'.join([node_name, nic_model, 'nic'])).get_interfaces()[0]
    net1.add_interface(nic_interface)
    nic_interface.set_mode('config')
    nic_interface.set_ip_addr(node_attribs['ip'])
    # postboot configuration is under 'post-boot' directory
    nodes[node_name].add_post_boot_upload_directory('post-boot','.')
    nodes[node_name].add_post_boot_execute(f'chmod +x post-boot/{node_name}.sh && ./post-boot/{node_name}.sh')

print(f'Creating a {distro_name} based slice named "{slice_name}" with nodes in {selected_site}')

# Submit the slice
slice.submit();
# Out:
# Retry: 8, Time: 305 sec
# <style type="text/css">
# #T_082d4 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_082d4 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_082d4 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_082d4_row0_col0, #T_082d4_row0_col1, #T_082d4_row1_col0, #T_082d4_row1_col1, #T_082d4_row2_col0, #T_082d4_row2_col1, #T_082d4_row3_col0, #T_082d4_row3_col1, #T_082d4_row4_col0, #T_082d4_row4_col1, #T_082d4_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_082d4_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_082d4">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_082d4_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_082d4_row0_col1" class="data row0 col1" >8a1bc512-463e-4e7e-963b-c7469c6b5dd8</td>
#     </tr>
#     <tr>
#       <td id="T_082d4_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_082d4_row1_col1" class="data row1 col1" >UDP LB Control Plane Testing with udplbd[develop], e2sar[e2sar-java] on ubuntu</td>
#     </tr>
#     <tr>
#       <td id="T_082d4_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_082d4_row2_col1" class="data row2 col1" >2025-02-13 20:22:31 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_082d4_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_082d4_row3_col1" class="data row3 col1" >2025-02-12 20:22:31 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_082d4_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_082d4_row4_col1" class="data row4 col1" >bbe0d94c-736b-477a-a2e6-fef9fe7ac9ca</td>
#     </tr>
#     <tr>
#       <td id="T_082d4_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_082d4_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8a974 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_8a974 th {
#   text-align: left;
# }
# #T_8a974 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8a974 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_8a974 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8a974_row0_col0, #T_8a974_row0_col1, #T_8a974_row0_col2, #T_8a974_row0_col3, #T_8a974_row0_col4, #T_8a974_row0_col5, #T_8a974_row0_col6, #T_8a974_row0_col7, #T_8a974_row0_col8, #T_8a974_row0_col9, #T_8a974_row0_col10, #T_8a974_row0_col13, #T_8a974_row0_col14, #T_8a974_row0_col15, #T_8a974_row1_col0, #T_8a974_row1_col1, #T_8a974_row1_col2, #T_8a974_row1_col3, #T_8a974_row1_col4, #T_8a974_row1_col5, #T_8a974_row1_col6, #T_8a974_row1_col7, #T_8a974_row1_col8, #T_8a974_row1_col9, #T_8a974_row1_col10, #T_8a974_row1_col13, #T_8a974_row1_col14, #T_8a974_row1_col15, #T_8a974_row2_col0, #T_8a974_row2_col1, #T_8a974_row2_col2, #T_8a974_row2_col3, #T_8a974_row2_col4, #T_8a974_row2_col5, #T_8a974_row2_col6, #T_8a974_row2_col7, #T_8a974_row2_col8, #T_8a974_row2_col9, #T_8a974_row2_col10, #T_8a974_row2_col13, #T_8a974_row2_col14, #T_8a974_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_8a974_row0_col11, #T_8a974_row1_col11, #T_8a974_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_8a974_row0_col12, #T_8a974_row1_col12, #T_8a974_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_8a974">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_8a974_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8a974_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_8a974_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_8a974_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_8a974_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_8a974_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_8a974_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_8a974_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_8a974_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_8a974_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_8a974_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_8a974_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_8a974_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_8a974_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_8a974_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_8a974_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8a974_row0_col0" class="data row0 col0" >1390ba42-d8d1-4f00-95b7-4a2d7e494389</td>
#       <td id="T_8a974_row0_col1" class="data row0 col1" >cpnode</td>
#       <td id="T_8a974_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_8a974_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_8a974_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_8a974_row0_col5" class="data row0 col5" >default_ubuntu_22</td>
#       <td id="T_8a974_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_8a974_row0_col7" class="data row0 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_8a974_row0_col8" class="data row0 col8" >SRI</td>
#       <td id="T_8a974_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_8a974_row0_col10" class="data row0 col10" >192.5.67.229</td>
#       <td id="T_8a974_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_8a974_row0_col12" class="data row0 col12" ></td>
#       <td id="T_8a974_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.229</td>
#       <td id="T_8a974_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_8a974_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_8a974_row1_col0" class="data row1 col0" >24f8eaf7-5144-41b9-ad8c-62fba5e1216b</td>
#       <td id="T_8a974_row1_col1" class="data row1 col1" >recver</td>
#       <td id="T_8a974_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_8a974_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_8a974_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_8a974_row1_col5" class="data row1 col5" >default_ubuntu_22</td>
#       <td id="T_8a974_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_8a974_row1_col7" class="data row1 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_8a974_row1_col8" class="data row1 col8" >SRI</td>
#       <td id="T_8a974_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_8a974_row1_col10" class="data row1 col10" >192.5.67.55</td>
#       <td id="T_8a974_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_8a974_row1_col12" class="data row1 col12" ></td>
#       <td id="T_8a974_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.55</td>
#       <td id="T_8a974_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_8a974_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_8a974_row2_col0" class="data row2 col0" >0f803535-e18b-4d6c-be91-df2d92edeba0</td>
#       <td id="T_8a974_row2_col1" class="data row2 col1" >sender</td>
#       <td id="T_8a974_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_8a974_row2_col3" class="data row2 col3" >32</td>
#       <td id="T_8a974_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_8a974_row2_col5" class="data row2 col5" >default_ubuntu_22</td>
#       <td id="T_8a974_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_8a974_row2_col7" class="data row2 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_8a974_row2_col8" class="data row2 col8" >SRI</td>
#       <td id="T_8a974_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_8a974_row2_col10" class="data row2 col10" >192.5.67.24</td>
#       <td id="T_8a974_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_8a974_row2_col12" class="data row2 col12" ></td>
#       <td id="T_8a974_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.24</td>
#       <td id="T_8a974_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_8a974_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7459b caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7459b th {
#   text-align: left;
# }
# #T_7459b tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7459b tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7459b .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7459b_row0_col0, #T_7459b_row0_col1, #T_7459b_row0_col2, #T_7459b_row0_col3, #T_7459b_row0_col4, #T_7459b_row0_col5, #T_7459b_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_7459b_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_7459b_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_7459b">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_7459b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_7459b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_7459b_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_7459b_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_7459b_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_7459b_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_7459b_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_7459b_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_7459b_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7459b_row0_col0" class="data row0 col0" >3a274596-f078-49f8-ae23-13c94fb26480</td>
#       <td id="T_7459b_row0_col1" class="data row0 col1" >site_bridge_net</td>
#       <td id="T_7459b_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_7459b_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_7459b_row0_col4" class="data row0 col4" >SRI</td>
#       <td id="T_7459b_row0_col5" class="data row0 col5" >192.168.1.0/24</td>
#       <td id="T_7459b_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_7459b_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_7459b_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bf85f caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_bf85f th {
#   text-align: left;
# }
# #T_bf85f tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bf85f tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bf85f .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bf85f_row0_col0, #T_bf85f_row0_col1, #T_bf85f_row0_col2, #T_bf85f_row0_col3, #T_bf85f_row0_col4, #T_bf85f_row0_col5, #T_bf85f_row0_col6, #T_bf85f_row0_col7, #T_bf85f_row0_col8, #T_bf85f_row0_col9, #T_bf85f_row0_col10, #T_bf85f_row0_col11, #T_bf85f_row0_col12, #T_bf85f_row1_col0, #T_bf85f_row1_col1, #T_bf85f_row1_col2, #T_bf85f_row1_col3, #T_bf85f_row1_col4, #T_bf85f_row1_col5, #T_bf85f_row1_col6, #T_bf85f_row1_col7, #T_bf85f_row1_col8, #T_bf85f_row1_col9, #T_bf85f_row1_col10, #T_bf85f_row1_col11, #T_bf85f_row1_col12, #T_bf85f_row2_col0, #T_bf85f_row2_col1, #T_bf85f_row2_col2, #T_bf85f_row2_col3, #T_bf85f_row2_col4, #T_bf85f_row2_col5, #T_bf85f_row2_col6, #T_bf85f_row2_col7, #T_bf85f_row2_col8, #T_bf85f_row2_col9, #T_bf85f_row2_col10, #T_bf85f_row2_col11, #T_bf85f_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_bf85f">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_bf85f_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_bf85f_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_bf85f_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_bf85f_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_bf85f_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_bf85f_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_bf85f_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_bf85f_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_bf85f_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_bf85f_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_bf85f_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_bf85f_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_bf85f_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bf85f_row0_col0" class="data row0 col0" >sender-sender_NIC_Basic_nic-p1</td>
#       <td id="T_bf85f_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_bf85f_row0_col2" class="data row0 col2" >sender</td>
#       <td id="T_bf85f_row0_col3" class="data row0 col3" >site_bridge_net</td>
#       <td id="T_bf85f_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_bf85f_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_bf85f_row0_col6" class="data row0 col6" ></td>
#       <td id="T_bf85f_row0_col7" class="data row0 col7" >06:C9:AC:19:B1:E0</td>
#       <td id="T_bf85f_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_bf85f_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_bf85f_row0_col10" class="data row0 col10" >192.168.0.1</td>
#       <td id="T_bf85f_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_bf85f_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_bf85f_row1_col0" class="data row1 col0" >recver-recver_NIC_Basic_nic-p1</td>
#       <td id="T_bf85f_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_bf85f_row1_col2" class="data row1 col2" >recver</td>
#       <td id="T_bf85f_row1_col3" class="data row1 col3" >site_bridge_net</td>
#       <td id="T_bf85f_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_bf85f_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_bf85f_row1_col6" class="data row1 col6" ></td>
#       <td id="T_bf85f_row1_col7" class="data row1 col7" >06:F5:D5:C8:1C:BE</td>
#       <td id="T_bf85f_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_bf85f_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_bf85f_row1_col10" class="data row1 col10" >192.168.0.2</td>
#       <td id="T_bf85f_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_bf85f_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_bf85f_row2_col0" class="data row2 col0" >cpnode-cpnode_NIC_Basic_nic-p1</td>
#       <td id="T_bf85f_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_bf85f_row2_col2" class="data row2 col2" >cpnode</td>
#       <td id="T_bf85f_row2_col3" class="data row2 col3" >site_bridge_net</td>
#       <td id="T_bf85f_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_bf85f_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_bf85f_row2_col6" class="data row2 col6" ></td>
#       <td id="T_bf85f_row2_col7" class="data row2 col7" >12:BA:FF:01:AE:FE</td>
#       <td id="T_bf85f_row2_col8" class="data row2 col8" >enp7s0</td>
#       <td id="T_bf85f_row2_col9" class="data row2 col9" >enp7s0</td>
#       <td id="T_bf85f_row2_col10" class="data row2 col10" >192.168.0.3</td>
#       <td id="T_bf85f_row2_col11" class="data row2 col11" >6</td>
#       <td id="T_bf85f_row2_col12" class="data row2 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 305 seconds

# %% [markdown]
# ## Get Slice Details
#
# If not creating a new slice, and just continuing work on an existing one, execute this cell (in addition to the preamble) and then any of the cells below will work.

# %%
# get slice details (if not creating new)
slice = fablib.get_slice(name=slice_name)
a = slice.show()
nets = slice.list_networks()
nodes = slice.list_nodes()

cpnode = slice.get_node(name="cpnode")    
sender = slice.get_node(name="sender")
recver = slice.get_node(name="recver")


# get node dataplane addresses
cpnode_addr = cpnode.get_interface(network_name=net_name).get_ip_addr()
sender_addr = sender.get_interface(network_name=net_name).get_ip_addr()
recver_addr = recver.get_interface(network_name=net_name).get_ip_addr()

sender_iface = sender.get_interface(network_name=net_name)
recver_iface = recver.get_interface(network_name=net_name)
# Out:
# <style type="text/css">
# #T_30040 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_30040 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_30040 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_30040_row0_col0, #T_30040_row0_col1, #T_30040_row1_col0, #T_30040_row1_col1, #T_30040_row2_col0, #T_30040_row2_col1, #T_30040_row3_col0, #T_30040_row3_col1, #T_30040_row4_col0, #T_30040_row4_col1, #T_30040_row5_col0, #T_30040_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_30040">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_30040_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_30040_row0_col1" class="data row0 col1" >8a1bc512-463e-4e7e-963b-c7469c6b5dd8</td>
#     </tr>
#     <tr>
#       <td id="T_30040_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_30040_row1_col1" class="data row1 col1" >UDP LB Control Plane Testing with udplbd[develop], e2sar[e2sar-java] on ubuntu</td>
#     </tr>
#     <tr>
#       <td id="T_30040_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_30040_row2_col1" class="data row2 col1" >2025-02-25 22:37:15 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_30040_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_30040_row3_col1" class="data row3 col1" >2025-02-12 20:22:31 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_30040_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_30040_row4_col1" class="data row4 col1" >bbe0d94c-736b-477a-a2e6-fef9fe7ac9ca</td>
#     </tr>
#     <tr>
#       <td id="T_30040_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_30040_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_be6a9 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_be6a9 th {
#   text-align: left;
# }
# #T_be6a9 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_be6a9 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_be6a9 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_be6a9_row0_col0, #T_be6a9_row0_col1, #T_be6a9_row0_col2, #T_be6a9_row0_col3, #T_be6a9_row0_col4, #T_be6a9_row0_col5, #T_be6a9_row0_col6, #T_be6a9_row0_col7, #T_be6a9_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_be6a9">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_be6a9_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_be6a9_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_be6a9_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_be6a9_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_be6a9_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_be6a9_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_be6a9_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_be6a9_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_be6a9_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_be6a9_row0_col0" class="data row0 col0" >3a274596-f078-49f8-ae23-13c94fb26480</td>
#       <td id="T_be6a9_row0_col1" class="data row0 col1" >site_bridge_net</td>
#       <td id="T_be6a9_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_be6a9_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_be6a9_row0_col4" class="data row0 col4" >SRI</td>
#       <td id="T_be6a9_row0_col5" class="data row0 col5" >192.168.1.0/24</td>
#       <td id="T_be6a9_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_be6a9_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_be6a9_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_67880 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_67880 th {
#   text-align: left;
# }
# #T_67880 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_67880 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_67880 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_67880_row0_col0, #T_67880_row0_col1, #T_67880_row0_col2, #T_67880_row0_col3, #T_67880_row0_col4, #T_67880_row0_col5, #T_67880_row0_col6, #T_67880_row0_col7, #T_67880_row0_col8, #T_67880_row0_col9, #T_67880_row0_col10, #T_67880_row0_col11, #T_67880_row0_col12, #T_67880_row0_col13, #T_67880_row0_col14, #T_67880_row0_col15, #T_67880_row1_col0, #T_67880_row1_col1, #T_67880_row1_col2, #T_67880_row1_col3, #T_67880_row1_col4, #T_67880_row1_col5, #T_67880_row1_col6, #T_67880_row1_col7, #T_67880_row1_col8, #T_67880_row1_col9, #T_67880_row1_col10, #T_67880_row1_col11, #T_67880_row1_col12, #T_67880_row1_col13, #T_67880_row1_col14, #T_67880_row1_col15, #T_67880_row2_col0, #T_67880_row2_col1, #T_67880_row2_col2, #T_67880_row2_col3, #T_67880_row2_col4, #T_67880_row2_col5, #T_67880_row2_col6, #T_67880_row2_col7, #T_67880_row2_col8, #T_67880_row2_col9, #T_67880_row2_col10, #T_67880_row2_col11, #T_67880_row2_col12, #T_67880_row2_col13, #T_67880_row2_col14, #T_67880_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_67880">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_67880_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_67880_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_67880_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_67880_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_67880_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_67880_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_67880_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_67880_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_67880_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_67880_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_67880_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_67880_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_67880_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_67880_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_67880_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_67880_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67880_row0_col0" class="data row0 col0" >1390ba42-d8d1-4f00-95b7-4a2d7e494389</td>
#       <td id="T_67880_row0_col1" class="data row0 col1" >cpnode</td>
#       <td id="T_67880_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_67880_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_67880_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_67880_row0_col5" class="data row0 col5" >default_ubuntu_22</td>
#       <td id="T_67880_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_67880_row0_col7" class="data row0 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_67880_row0_col8" class="data row0 col8" >SRI</td>
#       <td id="T_67880_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_67880_row0_col10" class="data row0 col10" >192.5.67.229</td>
#       <td id="T_67880_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_67880_row0_col12" class="data row0 col12" ></td>
#       <td id="T_67880_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.229</td>
#       <td id="T_67880_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_67880_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_67880_row1_col0" class="data row1 col0" >24f8eaf7-5144-41b9-ad8c-62fba5e1216b</td>
#       <td id="T_67880_row1_col1" class="data row1 col1" >recver</td>
#       <td id="T_67880_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_67880_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_67880_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_67880_row1_col5" class="data row1 col5" >default_ubuntu_22</td>
#       <td id="T_67880_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_67880_row1_col7" class="data row1 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_67880_row1_col8" class="data row1 col8" >SRI</td>
#       <td id="T_67880_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_67880_row1_col10" class="data row1 col10" >192.5.67.55</td>
#       <td id="T_67880_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_67880_row1_col12" class="data row1 col12" ></td>
#       <td id="T_67880_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.55</td>
#       <td id="T_67880_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_67880_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_67880_row2_col0" class="data row2 col0" >0f803535-e18b-4d6c-be91-df2d92edeba0</td>
#       <td id="T_67880_row2_col1" class="data row2 col1" >sender</td>
#       <td id="T_67880_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_67880_row2_col3" class="data row2 col3" >32</td>
#       <td id="T_67880_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_67880_row2_col5" class="data row2 col5" >default_ubuntu_22</td>
#       <td id="T_67880_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_67880_row2_col7" class="data row2 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_67880_row2_col8" class="data row2 col8" >SRI</td>
#       <td id="T_67880_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_67880_row2_col10" class="data row2 col10" >192.5.67.24</td>
#       <td id="T_67880_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_67880_row2_col12" class="data row2 col12" ></td>
#       <td id="T_67880_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.24</td>
#       <td id="T_67880_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_67880_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Start the UDPLBd container

# %%
# check if any dockers are running already and that we have compose and buildx installed by post-boot script
commands = [
    'docker container ls',
    'docker compose version',
    'docker buildx version'
]
execute_commands(cpnode, commands)
# Out:
# 	Executing "docker container ls" on node cpnode
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES
# 	Executing "docker compose version" on node cpnode
# Docker Compose version v2.27.0
# 	Executing "docker buildx version" on node cpnode
# github.com/docker/buildx v0.14.0 171fcbeb69d67c90ba7f44f41a9e418f6a6ec1da

# %%
# upload the mock config file for UDPLBd 
result = cpnode.upload_file(f'config/{udplbd_config}','lb_mock.yml')

# upload the GitHub SSH key onto the VM
result = cpnode.upload_file(github_key, vm_key_location)

# checkout UDPLBd (including the right branch) using that key
commands = [
    f"chmod go-rwx {vm_key_location}",
    f"GIT_SSH_COMMAND='ssh -i {vm_key_location} -o IdentitiesOnly=yes -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no' git clone -b {udplbd_branch} git@github.com:esnet/udplbd.git",
]

execute_commands(cpnode, commands)
# Out:
# 	Executing "chmod go-rwx /home/ubuntu/.ssh/github_ecdsa" on node cpnode
# 	Executing "GIT_SSH_COMMAND='ssh -i /home/ubuntu/.ssh/github_ecdsa -o IdentitiesOnly=yes -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no' git clone -b main git@github.com:esnet/udplbd.git" on node cpnode
#  fatal: destination path 'udplbd' already exists and is not an empty directory.

# %%
# copy configuration file into place, generate self-signed cert and start the UDPLBd container
commands = [
    f'cp lb_mock.yml ./udplbd/etc/config.yml',
    f'openssl req -x509 -newkey rsa:4096 -keyout udplbd/etc/server_key.pem -out udplbd/etc/server_cert.pem -sha256 -days 365 -nodes -subj "/CN=cpnode/subjectAltName=IP:{cpnode_addr}" -nodes',
    f'cd udplbd; docker compose up -d'
]

execute_commands(cpnode, commands)
# Out:
# 	Executing "cp lb_mock.yml ./udplbd/etc/config.yml" on node cpnode
# 	Executing "openssl req -x509 -newkey rsa:4096 -keyout udplbd/etc/server_key.pem -out udplbd/etc/server_cert.pem -sha256 -days 365 -nodes -subj "/CN=cpnode/subjectAltName=IP:192.168.0.3" -nodes" on node cpnode
#  .............................+...+.....+...+.+......+...+......+......+.....+.......+..+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*.......+....+...........+.......+...+...+.....+...............+.........+...+.......+..+.+...+.........+..+....+...........+....+.....+.+...+.....+......+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*....+....+........+.......+..+......+....+...+........+.........+.+...+........................+..+.........+.......+...+.................+.......+.....+.+..+..........+..+.+...........+...+......+...............+......+.+........+.+.....+.....................+..................+.+.......................+.+............+...+.....+............+...+.+.....+......+...+....+........+....+...........+..........+........+......+..........+......+...............+..+.......+...+..+.+........+.......+..............+....+.....+....+......+..+.......+....................+.......+...+...+.......................+....+..+....+..+............+.+.....+....+......+.....+.......+...+......+.....+.+....................+.............+..+...+..........+......+...+............+...........+.......+..+..........+......+.....+...+....+..+............................+..+....+...........+.............+.....+.+.....................+......+........+.+...+........+....+.....................+............+............+......+...+.....+....+......+...........+...+.+.....+.........+.......+.....+..............................+...+......+....+...+............+..................+..+.+..+...+.+....................+......+.........+...............+..........+...........+.......+.....+.......+.....................+..+..................+..........+...+......+.....+................+........+.+...+...........+......+...+..........+...+..+...........................+...+................+.....+....+......+..+.........+.........+.........+............+.............+......+.....+........................+.+.....+.+........+.+.....+.........+............+......+....+........+.......+...+.................+......+...............+.......+.....+...+...+.+...+.......................+..................+....+..+.+.....+...+..........+......+........+.+...............+..+.......+..+...+.+..............+...+...+.+......+........+.+.........+..+...................+.........+.........+.....+......+..........+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# .......+..+....+.........+..+.......+...+..+...............+...+....+.....+.+..+.............+.....+.......+.....+...+.........+.........+.+......+........+......+.+..+.+...........+.........+....+..+..........+...........+.......+...+..+.+..+.............+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*...+...+.+......+..+.......+...+..+.+...............+..+............+.............+........+.............+..+...............+...+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*...+......+....+............+......+........+.........+......+............+...............+....+.........+..+....+...........+....+.....+.+...+....................+.+...........+.........+.+...+..+.......+...+............+..+....+.........+.....+......+.+...+..+...+......+................+.............................+....+...+...+..............+......+.+........+.+.....+...............+.+..............+.+.....+.+..+............+.+..................+..+............+.+......+..............+.+...+.....+.+.....+.........+...+.........+.........+.......+...+...........+...+.+.........+..+......+...+....+...........+.........+.......+.....+...+...+...+......+......+...........................+..................+....+......+.....+....+......+..+.......+.....+.+..+......+.+.....+.+.........+......+........+..........+.................+.........................+...+......+.....+.........+....+..+...+......+......+.............+...+.....+............+.+......+...+...+........+.......+........+.......+...............+.....+.............+..+........................+....+............+.....+....+.....+..................+............+.........+....+...+............+..+.+.....+.............+.....+...............+.........................+.....+......+................+........+.........+...............+.+..............+...+..................+.........+.............+........+......+.+...+............+..+.......+........+......+.........+...+.......+.....+.+.....+.......+..+......+...............+.+.........+..+...............+.........+....+.....+...............+....+..+...+.+......+......+..+.........................+........+............+.+..+....+........+...+.......+.....+.+...........+.+..+.............+...+.........+.....+......+.......+..................+...........+.............+...........+.........+.......+......+.....+...+................+......+........+......+...+.+..+....+.....+.........+..........+....................+.+.........+.....+.......+..+...+....+.....+.........+......+...+.+......+...+......+......+........+...+.......+...+..+...............+.......+......+.....+....+...+..............................+......+.....+............+....+.........+...........+...............+...+...+...............+.......+...+.........+...+..+...+.......+...+........+...+.+.........+...........+...+.+......+....................+.............+........+....+...+..+....+......+........+.+..+...+.+...+...+.......................+....+........+.............+...........+...+...+...................+...............+......+..+.+...........+.+..+...+.......+...........+.+...+..+.+........................+........+...+...+.........+...+...+..........+............+.....+...+.....................+......+..........+..+.......+...........+...+.+........+.......+...+..+.+..............+......+...+.+......+.....+..........+............+..+..........+...+..+......+.............+............+..+.+......+.....+.............+.....+......+......+....+..+...................+...............+...........+....+...+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# -----
#  	Executing "cd udplbd; docker compose up -d" on node cpnode
# #0 building with "default" instance using docker driver
#
# #1 [udplbd internal] load build definition from Dockerfile
# #1 transferring dockerfile: 806B done
# #1 DONE 0.0s
#
# #2 [udplbd internal] load metadata for docker.io/library/golang:1.22
#  time="2025-02-13T19:44:38Z" level=warning msg="/home/ubuntu/udplbd/docker-compose.yml: `version` is obsolete"
#  udplbd Pulling
#  udplbd Warning pull access denied for udplbd, repository does not exist or may require 'docker login': denied: requested access to the resource is denied
#  #2 DONE 0.6s
#
# #3 [udplbd internal] load metadata for docker.io/library/debian:bookworm-slim
# #3 DONE 0.6s
#
# #4 [udplbd internal] load .dockerignore
# #4 transferring context: 2B done
# #4 DONE 0.0s
#
# #5 [udplbd builder 1/6] FROM docker.io/library/golang:1.22@sha256:1cf6c45ba39db9fd6db16922041d074a63c935556a05c5ccb62d181034df7f02
# #5 DONE 0.0s
#
# #6 [udplbd udplbd 1/4] FROM docker.io/library/debian:bookworm-slim@sha256:40b107342c492725bc7aacbe93a49945445191ae364184a6d24fedb28172f6f7
# #6 DONE 0.0s
#
# #7 [udplbd internal] load build context
# #7 transferring context: 11.07kB done
# #7 DONE 0.0s
#
# #8 [udplbd builder 3/6] COPY go.mod go.sum ./
# #8 CACHED
#
# #9 [udplbd builder 2/6] WORKDIR /app
# #9 CACHED
#
# #10 [udplbd builder 4/6] RUN go mod download && go mod verify
# #10 CACHED
#
# #11 [udplbd builder 5/6] COPY . .
# #11 DONE 0.1s
#
# #12 [udplbd builder 6/6] RUN --mount=type=cache,target=/root/.cache/go-build make build
# #12 0.163 git describe
# #12 0.164 v0.3.3-1-gc494b90
# #12 0.165 go build -v -ldflags "-X 'github.com/esnet/udplbd/pkg/build.Build=v0.3.3-1-gc494b90'" -o bin/udplbd github.com/esnet/udplbd
# #12 DONE 2.5s
#
# #13 [udplbd udplbd 2/4] RUN --mount=target=/var/lib/apt/lists,type=cache,sharing=locked     --mount=target=/var/cache/apt,type=cache,sharing=locked     set -eux; 	apt-get update; 	apt-get install -y --no-install-recommends 		ca-certificates 		openssl 	;
# #13 CACHED
#
# #14 [udplbd udplbd 3/4] COPY --from=builder /app/bin/udplbd /usr/bin/udplbd
# #14 CACHED
#
# #15 [udplbd udplbd 4/4] COPY ./frontend /frontend
# #15 CACHED
#
# #16 [udplbd] exporting to image
# #16 exporting layers done
# #16 writing image sha256:bc7f1561cecbf2122fb35eee09b9b96e0c84b6d22231662458fa55ce7fef3ba7 done
# #16 naming to docker.io/library/udplbd:latest done
# #16 DONE 0.0s
#   Container udplbd-udplbd-1  Creating
#    Container udplbd-udplbd-1  Created
#    Container udplbd-udplbd-1  Starting
#    Container udplbd-udplbd-1  Started

# %%
# check the logs
commands = [
    'docker compose ls',
    'cd udplbd; docker compose logs'
]

execute_commands(cpnode, commands)

# %%
# if you need to restart it, this is the stop part
commands = [
    'cd udplbd; docker compose stop; docker compose rm -f; docker image rm udplbd'
]

execute_commands(cpnode, commands)
# Out:
# 	Executing "cd udplbd; docker compose stop; docker compose rm -f; docker image rm udplbd" on node cpnode
# Going to remove udplbd-udplbd-1
#  time="2025-02-13T19:44:26Z" level=warning msg="/home/ubuntu/udplbd/docker-compose.yml: `version` is obsolete"
#  Container udplbd-udplbd-1  Stopping
#  Container udplbd-udplbd-1  Stopped
# time="2025-02-13T19:44:27Z" level=warning msg="/home/ubuntu/udplbd/docker-compose.yml: `version` is obsolete"
#  Container udplbd-udplbd-1  Removing
#  Untagged: udplbd:latest
# Deleted: sha256:bc7f1561cecbf2122fb35eee09b9b96e0c84b6d22231662458fa55ce7fef3ba7
#   Container udplbd-udplbd-1  Removed

# %% [markdown]
# ## Download and install E2SAR deb

# %%
# install github ssh key and set up build environment variables for interactive logins
commands = [
    f"chmod go-rwx {vm_key_location}",
    f"echo 'export LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64' >> ~/.profile",
    f"echo 'export LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64' >> ~/.bashrc",
]

for node in [sender, recver]:    
    # upload the GitHub SSH key onto the VM
    result = node.upload_file(github_key, vm_key_location)
    execute_commands(node, commands)
# Out:
# 	Executing "chmod go-rwx /home/ubuntu/.ssh/github_ecdsa" on node sender
# 	Executing "echo 'export LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64' >> ~/.profile" on node sender
# 	Executing "echo 'export LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64' >> ~/.bashrc" on node sender
# 	Executing "chmod go-rwx /home/ubuntu/.ssh/github_ecdsa" on node recver
# 	Executing "echo 'export LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64' >> ~/.profile" on node recver
# 	Executing "echo 'export LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64' >> ~/.bashrc" on node recver

# %%
##This block is to upload a commit sign key. Not needed 

# commands = [
#     f"chmod go-rwx {sign_key_location}",
#     f"git config --global gpg.format ssh",
#     f"git config --global user.signingkey {sign_key_location}",
# ]
# for node in [sender, recver]:    
#     # upload the GitHub Signing SSH key onto the VM
#     result = node.upload_file(signing_key, sign_key_location)
#     print(result)
#     execute_commands(node, commands)
# Out:
# -rw-------   1 1000     1000          419 14 Feb 01:47 ?
# 	Executing "chmod go-rwx /home/ubuntu/.ssh/signing" on node sender
# 	Executing "git config --global gpg.format ssh" on node sender
# 	Executing "git config --global user.signingkey /home/ubuntu/.ssh/signing" on node sender
# -rw-------   1 1000     1000          419 14 Feb 01:47 ?
# 	Executing "chmod go-rwx /home/ubuntu/.ssh/signing" on node recver
# 	Executing "git config --global gpg.format ssh" on node recver
# 	Executing "git config --global user.signingkey /home/ubuntu/.ssh/signing" on node recver

# %%
#download boost and grpc dependencies from releases
commands = [
    f"wget -q -O e2sar-release.deb {e2sar_release_url}",
    f"sudo apt -yq install ./e2sar-release.deb",
]
 
execute_commands([sender, recver], commands)

# %% [markdown]
# ## Download and build E2SAR-JAVA

# %%
#Clone E2SAR-java repo and set enviroment variables
commands = [
    f"GIT_SSH_COMMAND='ssh -i {vm_key_location} -o IdentitiesOnly=yes -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no' git clone git@github.com:JeffersonLab/e2sar-java.git",
]
 
execute_commands([sender, recver], commands)
# Out:
# 	Executing "GIT_SSH_COMMAND='ssh -i /home/ubuntu/.ssh/github_ecdsa -o IdentitiesOnly=yes -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no' git clone git@github.com:JeffersonLab/e2sar-java.git" on node sender
#  Cloning into 'e2sar-java'...
# Warning: Permanently added 'github.com' (ED25519) to the list of known hosts.
#  	Executing "GIT_SSH_COMMAND='ssh -i /home/ubuntu/.ssh/github_ecdsa -o IdentitiesOnly=yes -o UserKnownHostsFile=/dev/null -o StrictHostKeyChecking=no' git clone git@github.com:JeffersonLab/e2sar-java.git" on node recver
#  Cloning into 'e2sar-java'...
# Warning: Permanently added 'github.com' (ED25519) to the list of known hosts.

# %%
#set JAVA_HOME enviroment variables
java_home = '/usr/lib/jvm/java-1.17.0-openjdk-amd64' ## probably have to change this depending on OS. Tested on Ubuntu 22.04
commands = [
    f"echo 'export JAVA_HOME={java_home}' >> ~/.profile",
    f"echo 'export JAVA_HOME={java_home}' >> ~/.bashrc",
]
 
execute_commands([sender, recver], commands)
# Out:
# 	Executing "echo 'export JAVA_HOME=/usr/lib/jvm/java-1.17.0-openjdk-amd64' >> ~/.profile" on node sender
# 	Executing "echo 'export JAVA_HOME=/usr/lib/jvm/java-1.17.0-openjdk-amd64' >> ~/.bashrc" on node sender
# 	Executing "echo 'export JAVA_HOME=/usr/lib/jvm/java-1.17.0-openjdk-amd64' >> ~/.profile" on node recver
# 	Executing "echo 'export JAVA_HOME=/usr/lib/jvm/java-1.17.0-openjdk-amd64' >> ~/.bashrc" on node recver

# %%
#Building the JNI Shared library
#Might have to set PKG_CONFIG_PATH for cmake build to work. Works without pkg_config_path on 22.04
commands = [
    f"cd e2sar-java; JAVA_HOME={java_home} cmake -S . -B build",
    f"cd e2sar-java; JAVA_HOME={java_home} cmake --build build",
]

execute_commands([sender, recver], commands)

# %%
#Compiling Java code
commands = [
    f"cd e2sar-java; mvn clean compile",
]

execute_commands([sender, recver], commands)
# Out:
# 	Executing "cd e2sar-java; mvn clean compile" on node sender
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ----------------------< org.jlab.hpdf:e2sar-java >----------------------
# [INFO] Building e2sar-java 0.0.1
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ e2sar-java ---
# [INFO] Deleting /home/ubuntu/e2sar-java/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:compile (default-compile) @ e2sar-java ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 17 source files to /home/ubuntu/e2sar-java/target/classes
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  1.213 s
# [INFO] Finished at: 2025-02-12T20:53:09Z
# [INFO] ------------------------------------------------------------------------
# 	Executing "cd e2sar-java; mvn clean compile" on node recver
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ----------------------< org.jlab.hpdf:e2sar-java >----------------------
# [INFO] Building e2sar-java 0.0.1
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ e2sar-java ---
# [INFO] Deleting /home/ubuntu/e2sar-java/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:compile (default-compile) @ e2sar-java ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 17 source files to /home/ubuntu/e2sar-java/target/classes
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  1.222 s
# [INFO] Finished at: 2025-02-12T20:53:13Z
# [INFO] ------------------------------------------------------------------------

# %% [markdown]
# ## Running Unit tests

# %%
##IMPORTANT MAVEN ARGUMENTS NEEDED FOR TESTS
# Need to specify -Djava.library.path for linking with the jnie2sar.so built in the step above. Maven surefire tests do not pick this up directly so it has to be encapsulated as -DargLine='-Djava.library.path=build/'
# -Dtest="" is needed to specify class/package of tests with pattern. If this is not specified then all classes with *TEST* will be run by maven surefire

commands = [
    f"cd e2sar-java; LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64 mvn -DargLine='-Djava.library.path=build/' test -Dtest='org.jlab.hpdf.unit.**'",
]

execute_commands([sender, recver], commands)
# Out:
# 	Executing "cd e2sar-java; LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64 mvn -DargLine='-Djava.library.path=build/' test -Dtest='org.jlab.hpdf.unit.**'" on node sender
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ----------------------< org.jlab.hpdf:e2sar-java >----------------------
# [INFO] Building e2sar-java 0.0.1
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:compile (default-compile) @ e2sar-java ---
# [INFO] Nothing to compile - all classes are up to date
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:testCompile (default-testCompile) @ e2sar-java ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 7 source files to /home/ubuntu/e2sar-java/target/test-classes
# [INFO]
# [INFO] --- maven-surefire-plugin:3.5.2:test (default-test) @ e2sar-java ---
# [INFO] Using auto detected provider org.apache.maven.surefire.junitplatform.JUnitPlatformProvider
# [INFO]
# [INFO] -------------------------------------------------------
# [INFO]  T E S T S
# [INFO] -------------------------------------------------------
# [INFO] Running org.jlab.hpdf.unit.E2sarLbCpTest
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.087 s -- in org.jlab.hpdf.unit.E2sarLbCpTest
# [INFO] Running org.jlab.hpdf.unit.E2sarReassemblerTest
# DPReasTest1: Test segmentation and reassembly on local host with no control plane (no segmentation)
# This reassembler has 1 receive threads and is listening on ports 10000:10000 using portRange 0
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS.' of length 66
# Sent 5 data frames
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 0 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 1 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 2 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 3 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 4 and data id 1285
# NO EVENT LOSS
# DPReasTest2: Test segmentation and reassembly on local host with no control plane (basic segmentation)
# This reassembler has 1 receive threads and is listening on ports 10000:10000 using portRange 0
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS.' of length 66
# Sent 25 data frames
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 0 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 1 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 2 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 3 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 4 and data id 1285
# NO EVENT LOSS
# DPReasTest3: Test creationg of reassemblers with different parameters)
# This reassembler has 1 receive threads and is listening on ports 19522:19522 using portRange 0
# This reassembler has 4 receive threads and is listening on ports 19522:19525 using portRange 2
# This reassembler has 7 receive threads and is listening on ports 19522:19529 using portRange 3
# This reassembler has 4 receive threads and is listening on ports 19522:20545 using portRange 10
# This reassembler has 4 receive threads and is listening on ports 19522:19523 using portRange 1
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 20.73 s -- in org.jlab.hpdf.unit.E2sarReassemblerTest
# [INFO] Running org.jlab.hpdf.unit.E2sarEjfatUriTest
# ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020&data=192.188.29.20
# ejfat://[2001:4860:0:2001::68]:18020/lb/36?sync=[2001:4860:0:2031::68]:19020&data=[2001:4860:0:2021::68] vs ejfat://[2001:4860:0:2001::68]:18020/lb/36?data=[2001:4860:0:2021::68]&sync=[2001:4860:0:2031::68]:19020
# ejfats://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020 vs ejfats://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020
# ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020 vs ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020
# ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020 vs ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020
# ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020&sessionid=mysessionid vs ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020&sessionid=mysessionid
# ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020&data=192.188.29.20 vs ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020&data=192.188.29.20
# ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020 vs ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020
# ejfat://token@192.188.29.6:18020/lb/36 vs ejfat://token@192.188.29.6:18020/lb/36
# ejfat://token@192.188.29.6:18020/lb/36?data=192.188.29.20 vs ejfat://token@192.188.29.6:18020/lb/36?data=192.188.29.20
# ejfat://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020 vs ejfat://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020
# ejfat://token@192.188.29.6:18020/ vs ejfat://token@192.188.29.6:18020/
# ejfat://token@192.188.29.6:18020/ vs ejfat://token@192.188.29.6:18020
# ejfat://token@192.188.29.6:18020/?sync=192.188.29.6:19020 vs ejfat://token@192.188.29.6:18020/?sync=192.188.29.6:19020
# [INFO] Tests run: 17, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.036 s -- in org.jlab.hpdf.unit.E2sarEjfatUriTest
# [INFO] Running org.jlab.hpdf.unit.E2sarSyncTest
# DPSyncTest1: test sync thread sending 10 sync frames (once a second for 10 seconds)
# Running data test for 10 seconds against sync/10.251.100.122:12345
# Running sync test for 10 seconds /10.251.100.122:12345
# Sent 10 sync frames
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 16.34 s -- in org.jlab.hpdf.unit.E2sarSyncTest
# [INFO] Running org.jlab.hpdf.unit.E2sarSegmenterTest
# DPSegTest1: test segmenter (and sync thread) by sending 5 events via event queue with default MTU
# Running data test for 10 seconds against sync/192.168.254.1:12345 and data /10.250.100.123:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 5 data frames
# DPSegTest2: test segmenter (and sync thread) by sending 5 events via event queue with small MTU so 10 frames are sent
# Running data test for 10 seconds against sync/192.168.254.1:12345 and data /10.250.100.123:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 10 data frames
# DPSegTest3: test segmenter (and sync thread) by sending 5 events via sendEvent() with small MTU so 10 frames are sent
# Running data test for 10 seconds against sync/192.168.254.1:12345 and data /10.250.100.123:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 10 data frames
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 49.00 s -- in org.jlab.hpdf.unit.E2sarSegmenterTest
# [INFO]
# [INFO] Results:
# [INFO]
# [INFO] Tests run: 26, Failures: 0, Errors: 0, Skipped: 0
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  01:28 min
# [INFO] Finished at: 2025-02-12T20:55:14Z
# [INFO] ------------------------------------------------------------------------
# 	Executing "cd e2sar-java; LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64 mvn -DargLine='-Djava.library.path=build/' test -Dtest='org.jlab.hpdf.unit.**'" on node recver
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ----------------------< org.jlab.hpdf:e2sar-java >----------------------
# [INFO] Building e2sar-java 0.0.1
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:compile (default-compile) @ e2sar-java ---
# [INFO] Nothing to compile - all classes are up to date
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:testCompile (default-testCompile) @ e2sar-java ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 7 source files to /home/ubuntu/e2sar-java/target/test-classes
# [INFO]
# [INFO] --- maven-surefire-plugin:3.5.2:test (default-test) @ e2sar-java ---
# [INFO] Using auto detected provider org.apache.maven.surefire.junitplatform.JUnitPlatformProvider
# [INFO]
# [INFO] -------------------------------------------------------
# [INFO]  T E S T S
# [INFO] -------------------------------------------------------
# [INFO] Running org.jlab.hpdf.unit.E2sarLbCpTest
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.072 s -- in org.jlab.hpdf.unit.E2sarLbCpTest
# [INFO] Running org.jlab.hpdf.unit.E2sarReassemblerTest
# DPReasTest1: Test segmentation and reassembly on local host with no control plane (no segmentation)
# This reassembler has 1 receive threads and is listening on ports 10000:10000 using portRange 0
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS.' of length 66
# Sent 5 data frames
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 0 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 1 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 2 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 3 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 4 and data id 1285
# NO EVENT LOSS
# DPReasTest2: Test segmentation and reassembly on local host with no control plane (basic segmentation)
# This reassembler has 1 receive threads and is listening on ports 10000:10000 using portRange 0
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS.' of length 66
# Sent 25 data frames
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 0 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 1 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 2 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 3 and data id 1285
# Received message: THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1 SECONDS. of length 66 with event number 4 and data id 1285
# NO EVENT LOSS
# DPReasTest3: Test creationg of reassemblers with different parameters)
# This reassembler has 1 receive threads and is listening on ports 19522:19522 using portRange 0
# This reassembler has 4 receive threads and is listening on ports 19522:19525 using portRange 2
# This reassembler has 7 receive threads and is listening on ports 19522:19529 using portRange 3
# This reassembler has 4 receive threads and is listening on ports 19522:20545 using portRange 10
# This reassembler has 4 receive threads and is listening on ports 19522:19523 using portRange 1
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 20.74 s -- in org.jlab.hpdf.unit.E2sarReassemblerTest
# [INFO] Running org.jlab.hpdf.unit.E2sarEjfatUriTest
# ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020&data=192.188.29.20
# ejfat://[2001:4860:0:2001::68]:18020/lb/36?sync=[2001:4860:0:2031::68]:19020&data=[2001:4860:0:2021::68] vs ejfat://[2001:4860:0:2001::68]:18020/lb/36?data=[2001:4860:0:2021::68]&sync=[2001:4860:0:2031::68]:19020
# ejfats://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020 vs ejfats://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020
# ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020 vs ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020
# ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020 vs ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020
# ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020&sessionid=mysessionid vs ejfats://ejfat-lb.es.net:18020/lb/36?sync=192.188.29.6:19020&sessionid=mysessionid
# ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020&data=192.188.29.20 vs ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020&data=192.188.29.20
# ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020 vs ejfat://token@192.188.29.6:18020/lb/36?sync=192.188.29.6:19020
# ejfat://token@192.188.29.6:18020/lb/36 vs ejfat://token@192.188.29.6:18020/lb/36
# ejfat://token@192.188.29.6:18020/lb/36?data=192.188.29.20 vs ejfat://token@192.188.29.6:18020/lb/36?data=192.188.29.20
# ejfat://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020 vs ejfat://192.188.29.6:18020/lb/36?sync=192.188.29.6:19020
# ejfat://token@192.188.29.6:18020/ vs ejfat://token@192.188.29.6:18020/
# ejfat://token@192.188.29.6:18020/ vs ejfat://token@192.188.29.6:18020
# ejfat://token@192.188.29.6:18020/?sync=192.188.29.6:19020 vs ejfat://token@192.188.29.6:18020/?sync=192.188.29.6:19020
# [INFO] Tests run: 17, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.041 s -- in org.jlab.hpdf.unit.E2sarEjfatUriTest
# [INFO] Running org.jlab.hpdf.unit.E2sarSyncTest
# DPSyncTest1: test sync thread sending 10 sync frames (once a second for 10 seconds)
# Running data test for 10 seconds against sync/10.251.100.122:12345
# Running sync test for 10 seconds /10.251.100.122:12345
# Sent 10 sync frames
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 16.33 s -- in org.jlab.hpdf.unit.E2sarSyncTest
# [INFO] Running org.jlab.hpdf.unit.E2sarSegmenterTest
# DPSegTest1: test segmenter (and sync thread) by sending 5 events via event queue with default MTU
# Running data test for 10 seconds against sync/192.168.254.1:12345 and data /10.250.100.123:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 5 data frames
# DPSegTest2: test segmenter (and sync thread) by sending 5 events via event queue with small MTU so 10 frames are sent
# Running data test for 10 seconds against sync/192.168.254.1:12345 and data /10.250.100.123:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 10 data frames
# DPSegTest3: test segmenter (and sync thread) by sending 5 events via sendEvent() with small MTU so 10 frames are sent
# Running data test for 10 seconds against sync/192.168.254.1:12345 and data /10.250.100.123:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 10 data frames
# [INFO] Tests run: 3, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 49.00 s -- in org.jlab.hpdf.unit.E2sarSegmenterTest
# [INFO]
# [INFO] Results:
# [INFO]
# [INFO] Tests run: 26, Failures: 0, Errors: 0, Skipped: 0
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  01:28 min
# [INFO] Finished at: 2025-02-12T20:56:45Z
# [INFO] ------------------------------------------------------------------------

# %% [markdown]
# ## Running Live test

# %%
##IMPORTANT MAVEN ARGUMENTS NEEDED FOR TESTS
# Need to specify -Djava.library.path for linking with the jnie2sar.so built in the step above. Maven surefire tests do not pick this up directly so it has to be encapsulated as -DargLine='-Djava.library.path=build/'
# -Dtest="" is needed to specify class/package of tests with pattern. If this is not specified then all classes with *TEST* will be run by maven surefire

commands = [
    f"cd e2sar-java; EJFAT_URI='ejfats://udplbd@{cpnode_addr}:18347/lb/1?data=127.0.0.1&sync=192.168.88.199:1234' LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64 mvn -DargLine='-Djava.library.path=build/' test -Dtest='org.jlab.hpdf.live.**'",
]

execute_commands(sender, commands)
# Out:
# 	Executing "cd e2sar-java; EJFAT_URI='ejfats://udplbd@192.168.0.3:18347/lb/1?data=127.0.0.1&sync=192.168.88.199:1234' LD_LIBRARY_PATH=/usr/local/lib:/usr/local/lib64 mvn -DargLine='-Djava.library.path=build/' test -Dtest='org.jlab.hpdf.live.**'" on node sender
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ----------------------< org.jlab.hpdf:e2sar-java >----------------------
# [INFO] Building e2sar-java 0.0.1
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:compile (default-compile) @ e2sar-java ---
# [INFO] Nothing to compile - all classes are up to date
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ e2sar-java ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/ubuntu/e2sar-java/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.1:testCompile (default-testCompile) @ e2sar-java ---
# [INFO] Nothing to compile - all classes are up to date
# [INFO]
# [INFO] --- maven-surefire-plugin:3.5.2:test (default-test) @ e2sar-java ---
# [INFO] Using auto detected provider org.apache.maven.surefire.junitplatform.JUnitPlatformProvider
# [INFO]
# [INFO] -------------------------------------------------------
# [INFO]  T E S T S
# [INFO] -------------------------------------------------------
# [INFO] Running org.jlab.hpdf.live.E2sarSegmenterLiveTest
# DPSegLiveTest1: test segmenter (and sync thread) against UDPLBd by sending 5 events via event queue with default MTU so 5 frames are sent
# Creating segmenter using returned URI: ejfats://548aeeb214351637d2920197172be0cf0e728e36f27f285ad095138735c57439@192.168.0.3:18347/lb/44?sync=192.168.0.3:19531&data=192.0.2.1&data=[2001:db8::1]
# Running data test for 10 seconds against sync /192.168.0.3:19531 and data /192.0.2.1:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 2 SECONDS.' of length 66
# Sent 11 sync frames
# Sent 5 data frames
# DPSegLiveTest2: test segmenter (and sync thread) against UDPLBd by sending 5 events via event queue small MTU so 20 frames are sent
# Creating segmenter using returned URI: ejfats://ef0dfbaec5d149aeb7fcf343a2ebf9bae9d53f5fab482214aca7d33af626f2da@192.168.0.3:18347/lb/45?sync=192.168.0.3:19531&data=192.0.2.1&data=[2001:db8::1]
# Running data test for 10 seconds against sync /192.168.0.3:19531 and data /192.0.2.1:19522
# The event data is string 'THIS IS A VERY LONG EVENT MESSAGE WE WANT TO SEND EVERY 1/2 SECONDS.' of length 68
# Sent 11 sync frames
# Sent 20 data frames
# [INFO] Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 27.34 s -- in org.jlab.hpdf.live.E2sarSegmenterLiveTest
# [INFO] Running org.jlab.hpdf.live.E2sarLbCpLiveTest
# Last Updated2025-02-13T21:18:57.046406173Z
# Version String: c494b90235f0d8b4f3b862d85ad59fb788a49e3e,v0.3.3-1-gc494b90,v0.3.1
# Last Updated2025-02-13T21:18:59.738890008Z
# Last Updated2025-02-13T21:19:02.404489467Z
# [INFO] Tests run: 7, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 8.398 s -- in org.jlab.hpdf.live.E2sarLbCpLiveTest
# [INFO] Running org.jlab.hpdf.live.E2sarReassemblerLiveTest
# DPReasTest1: test reassembler and send state thread
# [ERROR] Tests run: 1, Failures: 1, Errors: 0, Skipped: 0, Time elapsed: 5.014 s <<< FAILURE! -- in org.jlab.hpdf.live.E2sarReassemblerLiveTest
# [ERROR] org.jlab.hpdf.live.E2sarReassemblerLiveTest.ReasLiveTest -- Time elapsed: 5.012 s <<< FAILURE!
# java.lang.AssertionError
# 	at org.jlab.hpdf.live.E2sarReassemblerLiveTest.ReasLiveTest(E2sarReassemblerLiveTest.java:61)
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:569)
# 	at java.base/java.util.ArrayList.forEach(ArrayList.java:1511)
# 	at java.base/java.util.ArrayList.forEach(ArrayList.java:1511)
#
# [INFO] Running org.jlab.hpdf.live.E2sarSyncLiveTest
# DPSyncLiveTest1: test sync thread against UDPLBd by sending 10 sync frames (once a second for 10 seconds)
# Creating segmenter using returned URI: ejfats://ee641eb78070d85dc8dde3552799bdcb9d43855caed543604cf176f8644441c4@192.168.0.3:18347/lb/52?sync=192.168.0.3:19531&data=192.0.2.1&data=[2001:db8::1]
# Running sync test for 10 seconds
# [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 16.37 s -- in org.jlab.hpdf.live.E2sarSyncLiveTest
# [INFO]
# [INFO] Results:
# [INFO]
# [ERROR] Failures:
# [ERROR]   E2sarReassemblerLiveTest.ReasLiveTest:61
# [INFO]
# [ERROR] Tests run: 11, Failures: 1, Errors: 0, Skipped: 0
# [INFO]
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD FAILURE
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  58.330 s
# [INFO] Finished at: 2025-02-13T21:19:24Z
# [INFO] ------------------------------------------------------------------------
# [ERROR] Failed to execute goal org.apache.maven.plugins:maven-surefire-plugin:3.5.2:test (default-test) on project e2sar-java: There are test failures.
# [ERROR]
# [ERROR] See /home/ubuntu/e2sar-java/target/surefire-reports for the individual test results.
# [ERROR] See dump files (if any exist) [date].dump, [date]-jvmRun[N].dump and [date].dumpstream.
# [ERROR] -> [Help 1]
# [ERROR]
# [ERROR] To see the full stack trace of the errors, re-run Maven with the -e switch.
# [ERROR] Re-run Maven using the -X switch to enable full debug logging.
# [ERROR]
# [ERROR] For more information about the errors and possible solutions, please read the following articles:
# [ERROR] [Help 1] http://cwiki.apache.org/confluence/display/MAVEN/MojoFailureException

# %% [markdown]
# ## Testing LBmon
# The following blocks are to install lbadm and lbmon in the default location ($HOME/e2sar-install/) and a simple test to reserve a LB from the sender and verify that the Lbmon works. (If this block is run later the LBid might be different, you would have to change the parameter in LBmon)
#
# If the Lbid is specified, the status of that reserved LB will be obtained, otherwise the Lb overview will be obtained. The appropriate instance/admin token must be given. For the status you need to copy the EJFAT_URI given by the Lbadm reserve operation to Lbmon.

# %%
commands = [
    f"EJFAT_URI='ejfats://udplbd@{cpnode_addr}:18347?sync=192.168.100.10:19020&data=192.168.101.10:18020' LD_LIBRARY_PATH=/usr/local/lib lbadm --reserve -e -v -6 -l myLib -d 01 -a 192.168.0.3",
]
execute_commands(sender,commands)

# %%
#using option e to suppress messages
commands = [
    f"EJFAT_URI='ejfats://udplbd@{cpnode_addr}:18347?sync=192.168.100.10:19020&data=192.168.101.10:18020' BOOST_ROOT=/usr/local/ LD_LIBRARY_PATH=/usr/local/lib lbadm --reserve -e -v -6 -l myLib -d 01 -a 192.168.0.3",
]
execute_commands(sender,commands)

# %%
#need to replace the EJFAT_URI created in the last step
ejfat_uri = "ejfats://999e421bf36382c8cb07f1ac3a355afccf9ed0e9e0e0d1e91947bc21d57170e6@192.168.0.3:18347/lb/1?sync=192.168.0.3:19531&data=192.0.2.1&data=[2001:db8::1]"
commands = [
    f"EJFAT_URI='{ejfat_uri}' BOOST_ROOT=/usr/local/ LD_LIBRARY_PATH=/usr/local/lib lbmon -v -6"
]
execute_commands(sender,commands)

# %%
#No need to replace uri, because we are using admin token and getting the overview of the LB
commands = [
    f"EJFAT_URI='ejfats://udplbd@192.168.0.3:18347' BOOST_ROOT=/usr/local/ LD_LIBRARY_PATH=/usr/local/lib lbmon -v -6"
]
execute_commands(sender,commands)

# %% [markdown]
# # Performance Testing

# %% [markdown]
# We use `e2sar_perf` program located under bin/ to test performance of segmenting and reassembly code. To reach higher rates we must update some system parameters first.
#
# Set up large socket buffers for receive and send (512M), 9k MTU on both sender and receiver and test that it worked. For rates over 1Gbps this is a must.

# %%
# set system-wide send and receive socket buffer limits to 512MB. e2sar_perf then will set SO_RCVBUF and SO_SNDBUF options on sending and receiving sockets
# this is system specific, so we don't do it through a file, but on command line. Normally this goes into /etc/sysctl.conf or /etc/sysctl.d/90-local.conf 
# or similar
commands = [
    f"sudo sysctl net.core.rmem_max=536870912",
    f"sudo sysctl net.core.wmem_max=536870912",
    f"sysctl net.core.wmem_max net.core.rmem_max"
]
execute_commands([sender, recver], commands);

# %%
# note  that in this slice we are guaranteed to have path MTU to be at least 9k, because FABRIC
# switches are configured for jumbo frames. In real life you need to consult your network administrator
# as simply setting MTU on sender and receiver may be insufficient.
mtu = '9000'
sender.execute(f"sudo ip link set dev {sender_iface.get_os_interface()} mtu {mtu}")
recver.execute(f"sudo ip link set dev {recver_iface.get_os_interface()} mtu {mtu}")

# test with no-defragment (DF=1) ping packets that path indeed supports MTU of 9000 
# (ping  packet  of 8972 payload length)
# send 10 packets and expect all of them to make it
stdout, stderr = sender.execute(f"sudo ping -f -s 8972 -c 10 -M do {recver_addr}")

# %%
# We need to setup the firewall to allow traffic to pass to the receiver

mgmt_iface_name = get_management_os_interface(recver)
data_iface = recver.get_interface(network_name=net_name)
data_iface_name = data_iface.get_os_interface()

print(f'Adding {mgmt_iface_name} and lo and data interface to trusted zone')
commands = [
    f'sudo firewall-cmd --permanent --zone=trusted --add-interface={data_iface_name}',
    f'sudo firewall-cmd --permanent --zone=trusted --add-interface=lo',
    f'sudo firewall-cmd --permanent --zone=trusted --add-interface={mgmt_iface_name}',
    f'for i in $(sudo firewall-cmd --zone=public --list-services); do sudo firewall-cmd --zone=public --permanent --remove-service=$i; done',
]
commands.append(f'sudo firewall-cmd --reload')
commands.append(f'sudo firewall-cmd --list-all --zone=public')

execute_commands([recver], commands)

# %%
import time

# for e2sar_perf only the data= part of the query is meaningful. sync= must be present but is ignored
# same for gRPC token, address and port (and lb id)
e2sarPerfURI = f"ejfat://useless@10.10.10.10:1234/lb/1?data={recver_addr}&sync=192.168.77.7:1234"
recverDuration = 20
mtu = 9000
rate = 15 # Gbps
length = 1000000 # event length in bytes
numEvents = 10000 # number of events to send
bufSize = 300 * 1024 * 1024 # 100MB send and receive buffers

recv_command = f"LD_LIBRARY_PATH=/usr/local/lib  e2sar_perf -r -u '{e2sarPerfURI}' -d {recverDuration} -b {bufSize} --ip {recver_addr} --port 19522"
send_command = f"LD_LIBRARY_PATH=/usr/local/lib  e2sar_perf -s -u '{e2sarPerfURI}' --mtu {mtu} --rate {rate} --length {length} -n {numEvents} -b {bufSize}"

# start the receiver for 10 seconds and log its output
print(f'Executing command {recv_command} on receiver')
recver.execute_thread(recv_command, output_file=f"{recver.get_name()}.perf.log")

# sleep 2 seconds to let receiver get going
time.sleep(2)

# start the sender in the foreground
print(f'Executing command {send_command} on sender')
stdout_send, stderr_send = sender.execute(send_command, output_file=f"{sender.get_name()}.perf.log")

print(f"Inspect {recver.get_name()}.perf.log file in your Jupyter container to see the results")

# %% [markdown]
# ## You can SSH into the sender/receiver nodes and run lbadm, lbmon, or compile, link and test your application against E2SAR

# %% [markdown]
# ## Manage the slice
#
# ### Extend

# %%
# Set end host to now plus 14 days
end_date = (datetime.now(timezone.utc) + timedelta(days=14)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice = fablib.get_slice(name=slice_name)

    slice.renew(end_date)
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 0, Time: 27 sec
# <style type="text/css">
# #T_10e6b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_10e6b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_10e6b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_10e6b_row0_col0, #T_10e6b_row0_col1, #T_10e6b_row1_col0, #T_10e6b_row1_col1, #T_10e6b_row2_col0, #T_10e6b_row2_col1, #T_10e6b_row3_col0, #T_10e6b_row3_col1, #T_10e6b_row4_col0, #T_10e6b_row4_col1, #T_10e6b_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_10e6b_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_10e6b">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_10e6b_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_10e6b_row0_col1" class="data row0 col1" >8a1bc512-463e-4e7e-963b-c7469c6b5dd8</td>
#     </tr>
#     <tr>
#       <td id="T_10e6b_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_10e6b_row1_col1" class="data row1 col1" >UDP LB Control Plane Testing with udplbd[develop], e2sar[e2sar-java] on ubuntu</td>
#     </tr>
#     <tr>
#       <td id="T_10e6b_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_10e6b_row2_col1" class="data row2 col1" >2025-02-25 22:37:15 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_10e6b_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_10e6b_row3_col1" class="data row3 col1" >2025-02-12 20:22:31 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_10e6b_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_10e6b_row4_col1" class="data row4 col1" >bbe0d94c-736b-477a-a2e6-fef9fe7ac9ca</td>
#     </tr>
#     <tr>
#       <td id="T_10e6b_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_10e6b_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f5689 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_f5689 th {
#   text-align: left;
# }
# #T_f5689 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f5689 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f5689 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f5689_row0_col0, #T_f5689_row0_col1, #T_f5689_row0_col2, #T_f5689_row0_col3, #T_f5689_row0_col4, #T_f5689_row0_col5, #T_f5689_row0_col6, #T_f5689_row0_col7, #T_f5689_row0_col8, #T_f5689_row0_col9, #T_f5689_row0_col10, #T_f5689_row0_col13, #T_f5689_row0_col14, #T_f5689_row0_col15, #T_f5689_row1_col0, #T_f5689_row1_col1, #T_f5689_row1_col2, #T_f5689_row1_col3, #T_f5689_row1_col4, #T_f5689_row1_col5, #T_f5689_row1_col6, #T_f5689_row1_col7, #T_f5689_row1_col8, #T_f5689_row1_col9, #T_f5689_row1_col10, #T_f5689_row1_col13, #T_f5689_row1_col14, #T_f5689_row1_col15, #T_f5689_row2_col0, #T_f5689_row2_col1, #T_f5689_row2_col2, #T_f5689_row2_col3, #T_f5689_row2_col4, #T_f5689_row2_col5, #T_f5689_row2_col6, #T_f5689_row2_col7, #T_f5689_row2_col8, #T_f5689_row2_col9, #T_f5689_row2_col10, #T_f5689_row2_col13, #T_f5689_row2_col14, #T_f5689_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_f5689_row0_col11, #T_f5689_row1_col11, #T_f5689_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_f5689_row0_col12, #T_f5689_row1_col12, #T_f5689_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_f5689">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_f5689_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_f5689_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_f5689_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_f5689_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_f5689_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_f5689_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_f5689_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_f5689_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_f5689_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_f5689_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_f5689_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_f5689_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_f5689_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_f5689_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_f5689_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_f5689_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f5689_row0_col0" class="data row0 col0" >1390ba42-d8d1-4f00-95b7-4a2d7e494389</td>
#       <td id="T_f5689_row0_col1" class="data row0 col1" >cpnode</td>
#       <td id="T_f5689_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_f5689_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_f5689_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_f5689_row0_col5" class="data row0 col5" >default_ubuntu_22</td>
#       <td id="T_f5689_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_f5689_row0_col7" class="data row0 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_f5689_row0_col8" class="data row0 col8" >SRI</td>
#       <td id="T_f5689_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_f5689_row0_col10" class="data row0 col10" >192.5.67.229</td>
#       <td id="T_f5689_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_f5689_row0_col12" class="data row0 col12" ></td>
#       <td id="T_f5689_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.229</td>
#       <td id="T_f5689_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_f5689_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_f5689_row1_col0" class="data row1 col0" >24f8eaf7-5144-41b9-ad8c-62fba5e1216b</td>
#       <td id="T_f5689_row1_col1" class="data row1 col1" >recver</td>
#       <td id="T_f5689_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_f5689_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_f5689_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_f5689_row1_col5" class="data row1 col5" >default_ubuntu_22</td>
#       <td id="T_f5689_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_f5689_row1_col7" class="data row1 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_f5689_row1_col8" class="data row1 col8" >SRI</td>
#       <td id="T_f5689_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_f5689_row1_col10" class="data row1 col10" >192.5.67.55</td>
#       <td id="T_f5689_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_f5689_row1_col12" class="data row1 col12" ></td>
#       <td id="T_f5689_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.55</td>
#       <td id="T_f5689_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_f5689_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_f5689_row2_col0" class="data row2 col0" >0f803535-e18b-4d6c-be91-df2d92edeba0</td>
#       <td id="T_f5689_row2_col1" class="data row2 col1" >sender</td>
#       <td id="T_f5689_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_f5689_row2_col3" class="data row2 col3" >32</td>
#       <td id="T_f5689_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_f5689_row2_col5" class="data row2 col5" >default_ubuntu_22</td>
#       <td id="T_f5689_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_f5689_row2_col7" class="data row2 col7" >sri-w1.fabric-testbed.net</td>
#       <td id="T_f5689_row2_col8" class="data row2 col8" >SRI</td>
#       <td id="T_f5689_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_f5689_row2_col10" class="data row2 col10" >192.5.67.24</td>
#       <td id="T_f5689_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_f5689_row2_col12" class="data row2 col12" ></td>
#       <td id="T_f5689_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@192.5.67.24</td>
#       <td id="T_f5689_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_f5689_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ae27b caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_ae27b th {
#   text-align: left;
# }
# #T_ae27b tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ae27b tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ae27b .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ae27b_row0_col0, #T_ae27b_row0_col1, #T_ae27b_row0_col2, #T_ae27b_row0_col3, #T_ae27b_row0_col4, #T_ae27b_row0_col5, #T_ae27b_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_ae27b_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_ae27b_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_ae27b">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_ae27b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_ae27b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_ae27b_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_ae27b_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_ae27b_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_ae27b_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_ae27b_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_ae27b_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_ae27b_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ae27b_row0_col0" class="data row0 col0" >3a274596-f078-49f8-ae23-13c94fb26480</td>
#       <td id="T_ae27b_row0_col1" class="data row0 col1" >site_bridge_net</td>
#       <td id="T_ae27b_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_ae27b_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_ae27b_row0_col4" class="data row0 col4" >SRI</td>
#       <td id="T_ae27b_row0_col5" class="data row0 col5" >192.168.1.0/24</td>
#       <td id="T_ae27b_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_ae27b_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_ae27b_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3b9f1 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_3b9f1 th {
#   text-align: left;
# }
# #T_3b9f1 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3b9f1 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3b9f1 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3b9f1_row0_col0, #T_3b9f1_row0_col1, #T_3b9f1_row0_col2, #T_3b9f1_row0_col3, #T_3b9f1_row0_col4, #T_3b9f1_row0_col5, #T_3b9f1_row0_col6, #T_3b9f1_row0_col7, #T_3b9f1_row0_col8, #T_3b9f1_row0_col9, #T_3b9f1_row0_col10, #T_3b9f1_row0_col11, #T_3b9f1_row0_col12, #T_3b9f1_row1_col0, #T_3b9f1_row1_col1, #T_3b9f1_row1_col2, #T_3b9f1_row1_col3, #T_3b9f1_row1_col4, #T_3b9f1_row1_col5, #T_3b9f1_row1_col6, #T_3b9f1_row1_col7, #T_3b9f1_row1_col8, #T_3b9f1_row1_col9, #T_3b9f1_row1_col10, #T_3b9f1_row1_col11, #T_3b9f1_row1_col12, #T_3b9f1_row2_col0, #T_3b9f1_row2_col1, #T_3b9f1_row2_col2, #T_3b9f1_row2_col3, #T_3b9f1_row2_col4, #T_3b9f1_row2_col5, #T_3b9f1_row2_col6, #T_3b9f1_row2_col7, #T_3b9f1_row2_col8, #T_3b9f1_row2_col9, #T_3b9f1_row2_col10, #T_3b9f1_row2_col11, #T_3b9f1_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_3b9f1">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_3b9f1_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_3b9f1_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_3b9f1_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_3b9f1_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_3b9f1_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_3b9f1_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_3b9f1_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_3b9f1_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_3b9f1_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_3b9f1_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_3b9f1_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_3b9f1_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_3b9f1_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3b9f1_row0_col0" class="data row0 col0" >sender-sender_NIC_Basic_nic-p1</td>
#       <td id="T_3b9f1_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_3b9f1_row0_col2" class="data row0 col2" >sender</td>
#       <td id="T_3b9f1_row0_col3" class="data row0 col3" >site_bridge_net</td>
#       <td id="T_3b9f1_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_3b9f1_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_3b9f1_row0_col6" class="data row0 col6" ></td>
#       <td id="T_3b9f1_row0_col7" class="data row0 col7" >06:C9:AC:19:B1:E0</td>
#       <td id="T_3b9f1_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_3b9f1_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_3b9f1_row0_col10" class="data row0 col10" >192.168.0.1</td>
#       <td id="T_3b9f1_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_3b9f1_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_3b9f1_row1_col0" class="data row1 col0" >recver-recver_NIC_Basic_nic-p1</td>
#       <td id="T_3b9f1_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_3b9f1_row1_col2" class="data row1 col2" >recver</td>
#       <td id="T_3b9f1_row1_col3" class="data row1 col3" >site_bridge_net</td>
#       <td id="T_3b9f1_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_3b9f1_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_3b9f1_row1_col6" class="data row1 col6" ></td>
#       <td id="T_3b9f1_row1_col7" class="data row1 col7" >06:F5:D5:C8:1C:BE</td>
#       <td id="T_3b9f1_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_3b9f1_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_3b9f1_row1_col10" class="data row1 col10" >192.168.0.2</td>
#       <td id="T_3b9f1_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_3b9f1_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_3b9f1_row2_col0" class="data row2 col0" >cpnode-cpnode_NIC_Basic_nic-p1</td>
#       <td id="T_3b9f1_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_3b9f1_row2_col2" class="data row2 col2" >cpnode</td>
#       <td id="T_3b9f1_row2_col3" class="data row2 col3" >site_bridge_net</td>
#       <td id="T_3b9f1_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_3b9f1_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_3b9f1_row2_col6" class="data row2 col6" ></td>
#       <td id="T_3b9f1_row2_col7" class="data row2 col7" >12:BA:FF:01:AE:FE</td>
#       <td id="T_3b9f1_row2_col8" class="data row2 col8" >enp7s0</td>
#       <td id="T_3b9f1_row2_col9" class="data row2 col9" >enp7s0</td>
#       <td id="T_3b9f1_row2_col10" class="data row2 col10" >192.168.0.3</td>
#       <td id="T_3b9f1_row2_col11" class="data row2 col11" >6</td>
#       <td id="T_3b9f1_row2_col12" class="data row2 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 27 seconds

# %% [markdown]
# ### Delete

# %%
slice = fablib.get_slice(slice_name)
slice.delete()
